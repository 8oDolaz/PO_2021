# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
basePath = r''
def read(path_to_file):
    return pd.read_csv(f'{base_path}{path_to_file}', encoding='utf16', sep=',')

# %%
allCoursesInfo = read('dataset/contents.csv')[:10000]

# %%
allCoursesInfo = allCoursesInfo.dropna()
allCoursesInfo
# Out:
#                                 content_id  content_type_id  \
# 0     000249F5-15E7-40FA-A835-CB6D34EF355E                1
# 1     0008020A-E57E-40BD-9196-AA20637936E1                1
# 3     000DDF9E-81D8-4612-A4DF-07E70705E0C9                1
# 6     000E9424-369E-43DD-BC66-D46A6E7A995C                1
# 7     00114246-96FC-4155-A563-EA55C52A5596                1
# ...                                    ...              ...
# 9993  3EF06C9F-D3CF-43BE-9175-180A8A76750B                1
# 9996  3EF56342-14BF-450D-B52B-7018555D3392                1
# 9997  3EF5B238-D046-45D8-B352-8D1D171F506E                1
# 9998  3EF65892-B503-4139-9283-41DD9250C849                1
# 9999  3EF9816D-2899-4277-8A37-BEA0ECD6F4D1                1
#
#       rpd_discipline_id  enable_type_id enable_type_change_date  \
# 0                  3870               4     2020-04-01 18:01:25
# 1                 10401               4     2020-04-01 18:01:25
# 3                 30650               1     2020-03-25 05:27:28
# 6                  3176               1     2020-03-04 04:10:51
# 7                     0               4     2020-04-01 18:01:25
# ...                 ...             ...                     ...
# 9993              49156               4     2020-04-01 18:01:25
# 9996              23350               1     2020-03-01 04:05:22
# 9997               3336               4     2020-04-01 18:01:25
# 9998              23320               4     2020-04-01 18:01:25
# 9999              16043               1     2020-03-02 04:50:40
#
#                                             normal_name  edition_number  \
# 0            Маркетинг в отраслях и сферах деятельности             1.0
# 1     Деловой английский язык для ресторанного бизне...             2.0
# 3                                  Электрический привод             2.0
# 6     Дошкольная педагогика. Развитие пространственн...             2.0
# 7          Криминалистика: тактика и методика. Задачник             1.0
# ...                                                 ...             ...
# 9993   История русской литературы первой трети XIX века             3.0
# 9996                                 История домов моды             3.0
# 9997                                   Общая психология             3.0
# 9998  Химия и технология кожи и меха: теоретические ...             2.0
# 9999  Правовое обеспечение профессиональной деятельн...             1.0
#
#                                            bdescription        ap_datefinish  \
# 0     Теории маркетинга посвящено множество достойны...  2031-07-11 00:00:00
# 1     Настоящее учебное пособие предназначено для ст...  2032-02-28 00:00:00
# 3     В учебнике даны основные сведения об электропр...  2031-09-30 00:00:00
# 6     В издании представлена методика диагностики пр...  2031-04-29 00:00:00
# 7     Главная цель настоящего учебного пособия — пом...  2030-04-23 00:00:00
# ...                                                 ...                  ...
# 9993  В учебнике раскрываются основные особенности и...  2030-09-21 00:00:00
# 9996  В учебном пособии излагается история моды от в...  2032-10-17 00:00:00
# 9997  Авторами представлен путь становления психолог...  2021-09-12 00:00:00
# 9998  Материалы учебного пособия подобраны в соответ...  2032-06-30 00:00:00
# 9999  В учебнике рассматриваются основные положения ...  2032-06-26 00:00:00
#
#                     Bdate  preview_bnumber  real_bnumber  new_edition_exists  \
# 0     2017-05-29 00:00:00             40.0         405.0                   1
# 1     2017-04-10 00:00:00             21.0         214.0                   1
# 3     2017-02-06 00:00:00             32.0         327.0                   0
# 6     2016-07-26 00:00:00             15.0         152.0                   0
# 7     2015-10-01 00:00:00             35.0         354.0                   1
# ...                   ...              ...           ...                 ...
# 9993  2011-11-21 00:00:00             20.0         208.0                   1
# 9996  2018-03-30 00:00:00             44.0         444.0                   0
# 9997  2013-04-08 00:00:00             50.0         525.0                   1
# 9998  2017-11-09 00:00:00             16.0         163.0                   1
# 9999  2017-08-01 00:00:00             35.0         356.0                   0
#
#       bbuyers_count  is_mediacourse  fits_exam
# 0                15               0          0
# 1                20               0          0
# 3                23               0          1
# 6                36               0          0
# 7                28               0          0
# ...             ...             ...        ...
# 9993            117               0          0
# 9996             15               0          0
# 9997            199               0          0
# 9998              2               0          0
# 9999              5               0          0
#
# [7434 rows x 16 columns]

# %%
names = allCoursesInfo.loc[:, 'normal_name'].values
description = allCoursesInfo.loc[:, 'bdescription'].values

# %%
import pymorphy2 as pm

morph = pm.MorphAnalyzer()

def back_to_normal(array):
    for element_i, element in enumerate(array):
        element = str(element).split(' ')
        result = []
        for word in element:
            result.append(morph.parse(word)[0].normal_form)
        array[element_i] = str(result)
    
    return array

names = back_to_normal(names)
description = back_to_normal(description)

# %%
import string

def delete_punctuation(array):
    for iteration in range(len(array)):
        for punc in string.punctuation:
            array[iteration] = array[iteration].replace(punc, '')
            
    return array

names = delete_punctuation(names)
description = delete_punctuation(description)

# %%
vectorizer = TfidfVectorizer()

names_weights = vectorizer.fit_transform(names)
description_weights = vectorizer.fit_transform(description)
description_weights.shape
# Out:
# (7434, 13321)

# %%
description
# Out:
# array(['теория маркетинг посвятить множество достойный книга и учебник известный зарубежный и российский автор в который раскрываться базовый подход к управление деятельность компания на рынок основать на обобщение опыт множество компания различный сфера деятельность а что если попробовать наоборот оттолкнуться не от общий теория маркетинг а от отраслевой специфика попробовать выявить и сравнить нюанс рынок потребительский товар и товар промышленный назначение банковский и страховой маркетинг товар и услуга согласиться что такой подход привносить новый колорит в познавательный аспект изучение маркетинговый деятельность предприятие кроме тот «отраслевой» взгляд на проблема маркетинг быть полезный выпускник бакалаври